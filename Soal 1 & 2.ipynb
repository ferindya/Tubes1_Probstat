# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
import pandas as pd
import numpy as np
import statistics

df = pd.read_csv('anggur.csv')

# Fungsi untuk menghitung rata-rata kandungan anggur
mean = df.mean()

# Fungsi untuk menghitung median kandungan anggur
median = df.median()

# Fungsi untuk menghitung modus kandungan anggur
modus = df.mode().iloc[0]

# Fungsi untuk menghitung standar deviasi kandungan anggur
std = df.std()

# Fungsi untuk menghitung variansi kandungan anggur
varians = df.var()

# Fungsi untuk menghitung range kandungan anggur
range = df.max() - df.min()

# Fungsi untuk menghitung nilai minimum kandungan anggur
nilaiMin = df.min()

# Fungsi untuk menghitung nilai maksimum kandungan anggur
nilaiMax = df.max()

# Fungsi untuk menghitung kuartil 1 kandungan anggur
kuartil1 = df.quantile(0.25)

# Fungsi untuk menghitung kuartil 2 (median) kandungan anggur
kuartil2 = df.quantile(0.50)

# Fungsi untuk menghitung kuartil 3 kandungan anggur
kuartil3 = df.quantile(0.75)

# Fungsi untuk menghitung IQR kandungan anggur
iqr = df.quantile(0.75) - df.quantile(0.25)

# Fungsi untuk menghitung nilai skewness kandungan anggur
skewness = df.skew()

# Fungsi untuk menghitung kurtosis kandungan anggur
kurtosis = df.kurt()

# Menampilkan tabel hasil perhitungan dari masing-masing atribut
columns = pd.DataFrame({'Mean': mean, 'Median': median, 'Modus': modus, 'Standar Deviasi': std, 'Variansi': varians, 'Range': range, 'Nilai Minimum': nilaiMin, 'Nilai Maksimum': nilaiMax, 'Kuartil 1': kuartil1, 'Kuartil 2': kuartil2, 'Kuartil 3': kuartil3, 'IQR': iqr, 'Skewness': skewness, 'Kurtosis': kurtosis})
table = columns.style.set_properties(**{'border': '1px solid black'})
table = columns.transpose()
display(table)
# Out:
#                  fixed acidity  volatile acidity  citric acid  residual sugar
# Mean                  7.152530          0.520839     0.270517        2.567104  \
# Median                7.150000          0.524850     0.272200        2.519430
# Modus                 6.540000          0.554600     0.301900        0.032555
# Standar Deviasi       1.201598          0.095848     0.049098        0.987915
# Variansi              1.443837          0.009187     0.002411        0.975977
# Range                 8.170000          0.665200     0.292900        5.518200
# Nilai Minimum         3.320000          0.139900     0.116700        0.032555
# Nilai Maksimum       11.490000          0.805100     0.409600        5.550755
# Kuartil 1             6.377500          0.456100     0.237800        1.896330
# Kuartil 2             7.150000          0.524850     0.272200        2.519430
# Kuartil 3             8.000000          0.585375     0.302325        3.220873
# IQR                   1.622500          0.129275     0.064525        1.324544
# Skewness             -0.028879         -0.197699    -0.045576        0.132638
# Kurtosis             -0.019292          0.161853    -0.104679       -0.042980
#
#                  chlorides  free sulfur dioxide  total sulfur dioxide
# Mean              0.081195            14.907679             40.290150  \
# Median            0.082167            14.860346             40.190000
# Modus             0.015122             0.194679             35.200000
# Standar Deviasi   0.020111             4.888100              9.965767
# Variansi          0.000404            23.893519             99.316519
# Range             0.125635            27.267847             66.810000
# Nilai Minimum     0.015122             0.194679              3.150000
# Nilai Maksimum    0.140758            27.462525             69.960000
# Kuartil 1         0.066574            11.426717             33.785000
# Kuartil 2         0.082167            14.860346             40.190000
# Kuartil 3         0.095312            18.313098             47.022500
# IQR               0.028738             6.886381             13.237500
# Skewness         -0.051319             0.007130             -0.024060
# Kurtosis         -0.246508            -0.364964              0.063950
#
#                   density        pH  sulphates    alcohol    quality
# Mean             0.995925  3.303610   0.598390  10.592280   7.958000
# Median           0.996000  3.300000   0.595000  10.610000   8.000000
# Modus            0.995900  3.340000   0.590000   9.860000   8.000000
# Standar Deviasi  0.002020  0.104875   0.100819   1.510706   0.902802
# Variansi         0.000004  0.010999   0.010164   2.282233   0.815051
# Range            0.013800  0.740000   0.670000   8.990000   5.000000
# Nilai Minimum    0.988800  2.970000   0.290000   6.030000   5.000000
# Nilai Maksimum   1.002600  3.710000   0.960000  15.020000  10.000000
# Kuartil 1        0.994600  3.230000   0.530000   9.560000   7.000000
# Kuartil 2        0.996000  3.300000   0.595000  10.610000   8.000000
# Kuartil 3        0.997200  3.370000   0.670000  11.622500   9.000000
# IQR              0.002600  0.140000   0.140000   2.062500   2.000000
# Skewness        -0.076883  0.147673   0.149199  -0.018991  -0.089054
# Kurtosis         0.016366  0.080910   0.064819  -0.131732   0.108291

# %% [markdown]
# # Boxplot dan Histogram fixed acidity
# Pada boxplot dapat dilihat bahwa nilai upper tail adalah

# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('anggur.csv')
print(df.boxplot(column = [df.columns[0]]))
print(df.hist(column = [df.columns[0]], bins=10, color="blue", edgecolor = "black"))
# Out:
# Axes(0.125,0.11;0.775x0.77)
# [[<Axes: title={'center': 'fixed acidity'}>]]

# %% [markdown]
# # Boxplot dan Histogram volatile acidity
# Pada boxplot dapat dilihat bahwa nilai upper tail adalah

# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('anggur.csv')
print(df.boxplot(column = [df.columns[1]]))
print(df.hist(column = [df.columns[1]], bins=10, color="blue", edgecolor = "black"))

# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('anggur.csv')
print(df.boxplot(column = [df.columns[2]]))
print(df.hist(column = [df.columns[2]], bins=25))
# Out:
# Axes(0.125,0.11;0.775x0.77)
# [[<Axes: title={'center': 'citric acid'}>]]

# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('anggur.csv')
print(df.boxplot(column = [df.columns[3]]))
print(df.hist(column = [df.columns[3]], bins=25))
# Out:
# Axes(0.125,0.11;0.775x0.77)
# [[<Axes: title={'center': 'residual sugar'}>]]

# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('anggur.csv')
print(df.boxplot(column = [df.columns[4]]))
print(df.hist(column = [df.columns[4]], bins=25))
# Out:
# Axes(0.125,0.11;0.775x0.77)
# [[<Axes: title={'center': 'chlorides'}>]]

# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('anggur.csv')
print(df.boxplot(column = [df.columns[5]]))
print(df.hist(column = [df.columns[5]], bins=25))
# Out:
# Axes(0.125,0.11;0.775x0.77)
# [[<Axes: title={'center': 'free sulfur dioxide'}>]]

# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('anggur.csv')
print(df.boxplot(column = [df.columns[6]]))
print(df.hist(column = [df.columns[6]], bins=25))
# Out:
# Axes(0.125,0.11;0.775x0.77)
# [[<Axes: title={'center': 'total sulfur dioxide'}>]]

# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('anggur.csv')
print(df.boxplot(column = [df.columns[7]]))
print(df.hist(column = [df.columns[7]], bins=25))
# Out:
# Axes(0.125,0.11;0.775x0.77)
# [[<Axes: title={'center': 'density'}>]]

# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('anggur.csv')
print(df.boxplot(column = [df.columns[8]]))
print(df.hist(column = [df.columns[8]], bins=25))
# Out:
# Axes(0.125,0.11;0.775x0.77)
# [[<Axes: title={'center': 'pH'}>]]

# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('anggur.csv')
print(df.boxplot(column = [df.columns[9]]))
print(df.hist(column = [df.columns[9]], bins=25))
# Out:
# Axes(0.125,0.11;0.775x0.77)
# [[<Axes: title={'center': 'sulphates'}>]]

# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('anggur.csv')
print(df.boxplot(column = [df.columns[10]]))
print(df.hist(column = [df.columns[10]], bins=25))
# Out:
# Axes(0.125,0.11;0.775x0.77)
# [[<Axes: title={'center': 'alcohol'}>]]

# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('anggur.csv')
print(df.boxplot(column = [df.columns[11]]))
print(df.hist(column = [df.columns[11]], bins=10))
# Out:
# Axes(0.125,0.11;0.775x0.77)
# [[<Axes: title={'center': 'quality'}>]]
