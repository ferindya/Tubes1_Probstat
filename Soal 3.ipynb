# %% [markdown]
# # Kelompok 8 - K01
# ## Anggota:
# ## - Asyifa Nurul Shafira (13521125)
# ## - Ferindya Aulia Berlinty (13521161)

# %% [markdown]
# # 3. Normality test

# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv('anggur.csv')
df = pd.DataFrame(data)
table = df.style.set_properties(**{'border': '1px solid black'})
display(table)
# Out:
# <style type="text/css">
# #T_f6b27_row0_col0, #T_f6b27_row0_col1, #T_f6b27_row0_col2, #T_f6b27_row0_col3, #T_f6b27_row0_col4, #T_f6b27_row0_col5, #T_f6b27_row0_col6, #T_f6b27_row0_col7, #T_f6b27_row0_col8, #T_f6b27_row0_col9, #T_f6b27_row0_col10, #T_f6b27_row0_col11, #T_f6b27_row1_col0, #T_f6b27_row1_col1, #T_f6b27_row1_col2, #T_f6b27_row1_col3, #T_f6b27_row1_col4, #T_f6b27_row1_col5, #T_f6b27_row1_col6, #T_f6b27_row1_col7, #T_f6b27_row1_col8, #T_f6b27_row1_col9, #T_f6b27_row1_col10, #T_f6b27_row1_col11, #T_f6b27_row2_col0, #T_f6b27_row2_col1, #T_f6b27_row2_col2, #T_f6b27_row2_col3, #T_f6b27_row2_col4, #T_f6b27_row2_col5, #T_f6b27_row2_col6, #T_f6b27_row2_col7, #T_f6b27_row2_col8, #T_f6b27_row2_col9, #T_f6b27_row2_col10, #T_f6b27_row2_col11, #T_f6b27_row3_col0, #T_f6b27_row3_col1, #T_f6b27_row3_col2, #T_f6b27_row3_col3, #T_f6b27_row3_col4, #T_f6b27_row3_col5, #T_f6b27_row3_col6, #T_f6b27_row3_col7, #T_f6b27_row3_col8, #T_f6b27_row3_col9, #T_f6b27_row3_col10, #T_f6b27_row3_col11, #T_f6b27_row4_col0, #T_f6b27_row4_col1, #T_f6b27_row4_col2, #T_f6b27_row4_col3, #T_f6b27_row4_col4, #T_f6b27_row4_col5, #T_f6b27_row4_col6, #T_f6b27_row4_col7, #T_f6b27_row4_col8, #T_f6b27_row4_col9, #T_f6b27_row4_col10, #T_f6b27_row4_col11, #T_f6b27_row5_col0, #T_f6b27_row5_col1, #T_f6b27_row5_col2, #T_f6b27_row5_col3, #T_f6b27_row5_col4, #T_f6b27_row5_col5, #T_f6b27_row5_col6, #T_f6b27_row5_col7, #T_f6b27_row5_col8, #T_f6b27_row5_col9, #T_f6b27_row5_col10, #T_f6b27_row5_col11, #T_f6b27_row6_col0, #T_f6b27_row6_col1, #T_f6b27_row6_col2, #T_f6b27_row6_col3, #T_f6b27_row6_col4, #T_f6b27_row6_col5, #T_f6b27_row6_col6, #T_f6b27_row6_col7, #T_f6b27_row6_col8, #T_f6b27_row6_col9, #T_f6b27_row6_col10, #T_f6b27_row6_col11, #T_f6b27_row7_col0, #T_f6b27_row7_col1, #T_f6b27_row7_col2, #T_f6b27_row7_col3, #T_f6b27_row7_col4, #T_f6b27_row7_col5, #T_f6b27_row7_col6, #T_f6b27_row7_col7, #T_f6b27_row7_col8, #T_f6b27_row7_col9, #T_f6b27_row7_col10, #T_f6b27_row7_col11, #T_f6b27_row8_col0, #T_f6b27_row8_col1, #T_f6b27_row8_col2, #T_f6b27_row8_col3, #T_f6b27_row8_col4, #T_f6b27_row8_col5, #T_f6b27_row8_col6, #T_f6b27_row8_col7, #T_f6b27_row8_col8, #T_f6b27_row8_col9, #T_f6b27_row8_col10, #T_f6b27_row8_col11, #T_f6b27_row9_col0, #T_f6b27_row9_col1, #T_f6b27_row9_col2, #T_f6b27_row9_col3, #T_f6b27_row9_col4, #T_f6b27_row9_col5, #T_f6b27_row9_col6, #T_f6b27_row9_col7, #T_f6b27_row9_col8, #T_f6b27_row9_col9, #T_f6b27_row9_col10, #T_f6b27_row9_col11, #T_f6b27_row10_col0, #T_f6b27_row10_col1, #T_f6b27_row10_col2, #T_f6b27_row10_col3, #T_f6b27_row10_col4, #T_f6b27_row10_col5, #T_f6b27_row10_col6, #T_f6b27_row10_col7, #T_f6b27_row10_col8, #T_f6b27_row10_col9, #T_f6b27_row10_col10, #T_f6b27_row10_col11, #T_f6b27_row11_col0, #T_f6b27_row11_col1, #T_f6b27_row11_col2, #T_f6b27_row11_col3, #T_f6b27_row11_col4, #T_f6b27_row11_col5, #T_f6b27_row11_col6, #T_f6b27_row11_col7, #T_f6b27_row11_col8, #T_f6b27_row11_col9, #T_f6b27_row11_col10, #T_f6b27_row11_col11, #T_f6b27_row12_col0, #T_f6b27_row12_col1, #T_f6b27_row12_col2, #T_f6b27_row12_col3, #T_f6b27_row12_col4, #T_f6b27_row12_col5, #T_f6b27_row12_col6, #T_f6b27_row12_col7, #T_f6b27_row12_col8, #T_f6b27_row12_col9, #T_f6b27_row12_col10, #T_f6b27_row12_col11, #T_f6b27_row13_col0, #T_f6b27_row13_col1, #T_f6b27_row13_col2, #T_f6b27_row13_col3, #T_f6b27_row13_col4, #T_f6b27_row13_col5, #T_f6b27_row13_col6, #T_f6b27_row13_col7, #T_f6b27_row13_col8, #T_f6b27_row13_col9, #T_f6b27_row13_col10, #T_f6b27_row13_col11, #T_f6b27_row14_col0, #T_f6b27_row14_col1, #T_f6b27_row14_col2, #T_f6b27_row14_col3, #T_f6b27_row14_col4, #T_f6b27_row14_col5, #T_f6b27_row14_col6, #T_f6b27_row14_col7, #T_f6b27_row14_col8, #T_f6b27_row14_col9, #T_f6b27_row14_col10, #T_f6b27_row14_col11, #T_f6b27_row15_col0, #T_f6b27_row15_col1, #T_f6b27_row15_col2, #T_f6b27_row15_col3, #T_f6b27_row15_col4, #T_f6b27_row15_col5, #T_f6b27_row15_col6, #T_f6b27_row15_col7, #T_f6b27_row15_col8, #T_f6b27_row15_col9, #T_f6b27_row15_col10, #T_f6b27_row15_col11, #T_f6b27_row16_col0, #T_f6b27_row16_col1, #T_f6b27_row16 ...

# %%
from scipy.stats import normaltest
import seaborn as sns

def normalityTest(df):
    k, pValue = normaltest(df)
    print("P-value yang didapat sebesar", pValue)
    if (pValue < 0.05):
        print("Hipotesis 0 ditolak sehingga data tidak berdistribusi normal.")
    else:
        print("Hipotesis 0 diterima sehingga data berdistribusi normal.")
    sns.histplot(df, kde=True)

# %% [markdown]
# # Fixed Acidity

# %%
# Menampilkan hasil normality test yang dikaitkan dengan histogram plot untuk fixed acidity

normalityTest(df['fixed acidity'])
# Out:
# P-value yang didapat sebesar 0.9308584274486692
# Hipotesis 0 diterima sehingga data berdistribusi normal.

# %% [markdown]
# # Volatile Acidity

# %%
# Menampilkan hasil normality test yang dikaitkan dengan histogram plot untuk volatile acidity

normalityTest(df['volatile acidity'])
# Out:
# P-value yang didapat sebesar 0.022581461594113835
# Hipotesis 0 ditolak sehingga data tidak berdistribusi normal.

# %% [markdown]
# # Citric Acid

# %%
# Menampilkan hasil normality test yang dikaitkan dengan histogram plot untuk citric acid

normalityTest(df['citric acid'])
# Out:
# P-value yang didapat sebesar 0.6816899375976969
# Hipotesis 0 diterima sehingga data berdistribusi normal.

# %% [markdown]
# # Residual Sugar

# %%
# Menampilkan hasil normality test yang dikaitkan dengan histogram plot untuk residual sugar

normalityTest(df['residual sugar'])
# Out:
# P-value yang didapat sebesar 0.2246670332131056
# Hipotesis 0 diterima sehingga data berdistribusi normal.

# %% [markdown]
# # Chlorides

# %%
# Menampilkan hasil normality test yang dikaitkan dengan histogram plot untuk chlorides

normalityTest(df['chlorides'])
# Out:
# P-value yang didapat sebesar 0.17048274704296862
# Hipotesis 0 diterima sehingga data berdistribusi normal.

# %% [markdown]
# # Free Sulfur Dioxide

# %%
# Menampilkan hasil normality test yang dikaitkan dengan histogram plot untuk free sulfur dioxide

normalityTest(df['free sulfur dioxide'])
# Out:
# P-value yang didapat sebesar 0.01743043451827735
# Hipotesis 0 ditolak sehingga data tidak berdistribusi normal.

# %% [markdown]
# # Total Sulfur Dioxide

# %%
# Menampilkan hasil normality test yang dikaitkan dengan histogram plot untuk total sulfur dioxide

normalityTest(df['total sulfur dioxide'])
# Out:
# P-value yang didapat sebesar 0.8488846101395726
# Hipotesis 0 diterima sehingga data berdistribusi normal.

# %% [markdown]
# # Density

# %%
# Menampilkan hasil normality test yang dikaitkan dengan histogram plot untuk density

normalityTest(df['density'])
# Out:
# P-value yang didapat sebesar 0.5985227325531981
# Hipotesis 0 diterima sehingga data berdistribusi normal.

# %% [markdown]
# # pH

# %%
# Menampilkan hasil normality test yang dikaitkan dengan histogram plot untuk pH

normalityTest(df['pH'])
# Out:
# P-value yang didapat sebesar 0.13678740824860436
# Hipotesis 0 diterima sehingga data berdistribusi normal.

# %% [markdown]
# # Sulphates

# %%
# Menampilkan hasil normality test yang dikaitkan dengan histogram plot untuk sulphates

normalityTest(df['sulphates'])
# Out:
# P-value yang didapat sebesar 0.13884318628391681
# Hipotesis 0 diterima sehingga data berdistribusi normal.

# %% [markdown]
# # Alcohol

# %%
# Menampilkan hasil normality test yang dikaitkan dengan histogram plot untuk alcohol

normalityTest(df['alcohol'])
# Out:
# P-value yang didapat sebesar 0.6790884901361043
# Hipotesis 0 diterima sehingga data berdistribusi normal.

# %% [markdown]
# # Quality

# %%
# Menampilkan hasil normality test yang dikaitkan dengan histogram plot untuk quality

normalityTest(df['quality'])
# Out:
# P-value yang didapat sebesar 0.3888139394184818
# Hipotesis 0 diterima sehingga data berdistribusi normal.

# %%
from scipy.stats import shapiro, probplot
import pylab

def print_result(stat,p):
    print("stat=%.3f, p=%.10f" %(stat, p), end=" ")
    if p>0.05:
        print("Normal")
    else:
        print("Tidak")

for cols in df:
    if(df[cols].dtype in accepted_data_type):
        print('================='+cols+'================')
        data = df[cols]
        stat, p = shapiro(data)
        print("Shapiro Test : ", end="")
        print_result(stat, p)
        probplot(data, dist="norm", plot=pylab)
        pylab.show()
# Out:
# =================fixed acidity================
# Shapiro Test : stat=0.999, p=0.8935267925 Normal
# =================volatile acidity================
# Shapiro Test : stat=0.997, p=0.0599304363 Normal
# =================citric acid================
# Shapiro Test : stat=0.998, p=0.2652290761 Normal
# =================residual sugar================
# Shapiro Test : stat=0.997, p=0.0449186452 Tidak
# =================chlorides================
# Shapiro Test : stat=0.998, p=0.1746553034 Normal
# =================free sulfur dioxide================
# Shapiro Test : stat=0.997, p=0.0425582714 Tidak
# =================total sulfur dioxide================
# Shapiro Test : stat=0.998, p=0.5367269516 Normal
# =================density================
# Shapiro Test : stat=0.999, p=0.8533204794 Normal
# =================pH================
# Shapiro Test : stat=0.998, p=0.1371351629 Normal
# =================sulphates================
# Shapiro Test : stat=0.997, p=0.1121428311 Normal
# =================alcohol================
# Shapiro Test : stat=0.998, p=0.5198704004 Normal
# =================quality================
# Shapiro Test : stat=0.896, p=0.0000000000 Tidak
